# %%
from kan.MultKAN import *
import torch

multkan = MultKAN(width=[2,[1,2],[2,1],1], grid=3, noise_scale_base=0.25,noise_scale=1.0)

# %%
x = torch.rand(size=(100,2)) * 2 - 1
multkan(x);

# %%
multkan.plot(beta=10000, scale=1)
